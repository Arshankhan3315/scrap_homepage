# %%
import pandas as pd

# %%
df=pd.read_csv('Yoga Studios - Arshan_Khan - yoga_Arshan_khan.csv')

# %%
df.head()
# Out:
#          City         State State Code        Country  \
# 0  Somerville         Texas         TX  United States
# 1      Canton  South Dakota         SD  United States
# 2    Hartford  South Dakota         SD  United States
# 3      Parker  South Dakota         SD  United States
# 4  Harrisburg  South Dakota         SD  United States
#
#                     yogaStudio1Name                        yogaStudio1Website  \
# 0          Yoga Pod College Station        https://yogapodcollegestation.com/
# 1                   Anytime Fitness           https://www.anytimefitness.com/
# 2    Lemke's Fitness & Training Co.  http://www.lemkesfitnessandtraining.com/
# 3  Santosha Studios Yoga & Wellness              https://santoshastudios.com/
# 4                         Tryon Gym    https://siouxfallsstorm.com/index.aspx
#
#                                   yogaStudio1Reviews  \
# 0  https://www.yellowpages.com/college-station-tx...
# 1  https://www.anytimefitness.com/gyms/3674/brand...
# ...

# %%
url=df['yogaStudio10Website'].to_list()

# %%
url
# Out:
# ['https://www.purebarre.com/location/college-station-tx',
#  'http://www.solvibestudio.com/',
#  'http://sdaerialarts.com/?utm_source=google&utm_medium=wix_google_business_profile&utm_campaign=16624094625952745451',
#  'https://rapidfitnessonline.com/',
#  'https://uptownwellnessacademy.com/',
#  'https://www.wellnesscollectivesd.com/',
#  'https://www.willowyogastudio.com/',
#  'http://yogaunitedatbrighton.com/',
#  'http://www.fbyogastudio.com/',
#  'https://prodigylife.com/',
#  'http://www.yogaoasis.com/',
#  'http://ilsy.net/',
#  'https://www.jaiyogacenter.com/',
#  'http://www.awakensanctuary.com/',
#  'http://www.urharmony.com/',
#  'http://www.mindthemat.com/',
#  'http://www.alllifeisyoga.org/',
#  'https://healthsport.com/?utm_source=Arcgoogle&utm_medium=local&utm_campaign=gmb_listing',
#  'http://www.yogacultureco.com/',
#  'https://www.someyogastudio.com/',
#  'https://www.snapfitness.com/us/gyms/arlington-mn/?utm_source=gmb&utm_medium=yext',
# ...

# %%
urls=['https://magnoliawellnesscenter.org/',
 'https://www.bringitomyoga.com/',
 'http://solmovementdenver.com/',
 'https://www.abideyogacleveland.com/',
 'https://www.hotworx.net/studio/myrtlebeach-carolinaforest501/',
 'http://www.studiomillswellness.com/',
 'http://ladiesfirstrocks.com/',
 'http://www.presentmomentyoga.com/',
 'http://www.shaktibuffalo.com/',
 'https://www.inhaleyoga.org/',
 'https://y2yoga.com/kingsley/',
 'http://www.downtowndesertyoga.com/',
 'http://portcitypoweryoga.com/?utm_source=google&utm_medium=wix_google_business_profile&utm_campaign=6580507011166792895',
 'https://www.highland-yoga.com/',
 'https://www.yogagallery.net/',
 'https://www.hotworx.net/',
 'https://bikramyoga.com/',
 'http://theyogasource.org/',
 'http://somelikeithotpoweryoga.com/',
 'https://www.blackswanyoga.com/',
 'http://www.yogasix.com/long-beach',
 'http://centerstreampilates.com/',
 'http://yogaloungehudson.com/',
 'http://www.artfitlubbock.com/',
 'http://1111yogastudio.net/',
 'http://trimethodwellness.com/',
 'http://www.amylynnyogastl.com/',
 'http://www.joyflowyoga.com/',
 'https://www.hotworx.net/studio/fremont',
 'http://www.southstreetyoga.com/#!contact/c16gk',
 'http://www.fitandfirestudios.com/',
 'http://jamesriveryoga.com/',
 'http://studio8wv.com/',
 'http://www.dragonflyhotyoga.com/',
 'https://www.salineperformance.com/',
 'https://www.elxryogalounge.com/',
 'http://ardmorepeaceyoga.com/',
 'http://www.themettacenterhealing.com/',
 'http://mokshayoga.com/',
 'http://www.studioyogabcs.com/',
 'https://www.innercharmyoga.com/',
 'https://www.hotworx.net/studio/springdale-har-ber/',
 'http://www.fydyoga.net/',
 'https://www.yogasix.com/mountain-view',
 'https://www.thesweatbox440.com/',
 'http://www.oneloveyoga.co/',
 'http://www.elementreeyogastudio.com/',
 'https://www.orangetheory.com/en-us/locations/georgia/milton/12635-crabapple-rd/?utm_medium=seo&utm_source=gg&utm_term=tombras&utm_campaign=reputationdotcom--National',
 'https://www.experienceyoga.com/',
 'http://www.yogasix.com/lake-oswego',
 'http://www.colibridiscoveries.com/',
 'http://www.yogawithumit.com/',
 'http://www.ishineyoga.com/',
 'http://ajanafitness.com/',
 'http://tpyoga.com/',
 'http://www.beewellyoga.com/',
 'http://www.happyhour.yoga/',
 'http://www.journeyyogastudio.com/?utm_source=google&utm_medium=wix_google_business_profile&utm_campaign=16019166335013523025',
 'http://www.innerawareness.net/contact.html',
 'https://www.purebarre.com/location/mooresville-nc',
 'http://www.gopiyogacenter.com/',
 'https://www.iynv.com/',
 'http://letsexperiment.com/',
 'https://www.hotworx.net/studio/peachtreecity',
 'https://www.onelifefitness.com/gyms/norfolk',
 'http://theyogaboxokc.com/',
 'https://www.yogacirclesc.com/',
 'http://brickcityyogastl.com/',
 'http://www.shivashaktiloka.com/',
 'http://www.yogasix.com/belle-isle',
 'https://www.districthotyoga.com/',
 'http://www.oregonfitnesscenter.com/',
 'http://www.orlandopoweryoga.com/',
 'http://www.energyoga.net/',
 'https://shineyogapbg.com/',
 'http://www.thewoodlandsyogastudio.com/',
 'http://www.peakyogaandwellness.com/',
 'https://www.optimisticelephant.com/',
 'https://www.orangetheory.com/en-us/locations/colorado/parker/12227-pine-bluffs-way-suite-205/?utm_medium=seo&utm_source=gg&utm_term=tombras&utm_campaign=reputationdotcom--National',
 'http://www.yogasix.com/fort-worth',
 'https://www.bodynbrain.com/pasadena',
 'https://theyogastudiotx.com/',
 'https://www.bigshouldersyoga.com/',
 'https://mysticmandala.org/',
 'http://www.jewelyogapdx.com/',
 'http://www.firelightyoga.com/',
 'http://www.parallel45.com/',
 'http://www.yogasix.com/slabtown',
 'https://www.schedulicity.com/scheduling/APT48D',
 'http://ardmorepeaceyoga.com/',
 'http://www.butterflyfitness.org/',
 'http://casitayogastudio.com/',
 'http://www.110yoga.com/',
 'http://www.soulvibeswithnatalie.com/',
 'http://focusstudioredmond.com/',
 'http://places.singleplatform.com/el-cerrito-yogo-bikram/menu?ref=google',
 'https://www.the-hidden-gem.store/',
 'https://www.lunarfitnessandwellness.com/',
 'http://www.rva.yoga/',
 'https://www.nkbyoga.com/',
 'http://www.fullcircleyogakc.com/',
 'http://bikramyogakaty.com/',
 'http://satorihotyoga.com/',
 'http://www.hustlehaven.com/',
 'http://www.pranaprenatalyoga.com/',
 'http://www.yoganowchicago.com/',
 'http://muddyfeetyoga.com/',
 'https://kcyogakula.com/',
 'https://www.ofrendayoga.com/',
 'http://www.mattapoisettwellness.com/',
 'https://www.studioyouniverse.com/',
 'https://www.sanctuaryyoga.us/',
 'https://www.gitayoga.net/',
 'https://www.hotworx.net/studio/fayetteville-college-ave',
 'http://www.ahhyoga.com/',
 'http://theyogashalautah.com/',
 'http://www.wipoweryoga.com/',
 'http://www.inbodyyogaacademy.com/']

# %%
from selenium import webdriver

# %%
driver=webdriver.Chrome()

# %%
import time
import requests
import pandas as pd
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager

# %%
# Set your ImgBB API key
IMGBB_API_KEY = "645e87f27853d747273d11171581788e"

# %%
# Setup Selenium WebDriver
chrome_options = Options()
chrome_options.add_argument("--headless")  # Run in headless mode
chrome_options.add_argument("--no-sandbox")
chrome_options.add_argument("--disable-dev-shm-usage")
chrome_options.add_argument("--start-maximized")  # Ensure full-screen mode
service = Service(ChromeDriverManager().install())
driver = webdriver.Chrome(service=service, options=chrome_options)

# %%
# Setup Selenium WebDriver
# Store results
results = []

for url in urls:
    try:
        driver.get(url)
        time.sleep(3)  # Allow time for the page to load

        # Get the total height of the webpage
        total_height = driver.execute_script("return document.body.scrollHeight")
        driver.set_window_size(1446, 893)  # Resize window to full page height

        # Take a full-page screenshot
        screenshot_path = f"screenshot_{urls.index(url)}.png"
        driver.save_screenshot(screenshot_path)
        print(f"Screenshot saved: {screenshot_path}")

        # Upload to ImgBB
        with open(screenshot_path, "rb") as file:
            response = requests.post(
                "https://api.imgbb.com/1/upload",
                params={"key": IMGBB_API_KEY},
                files={"image": file}
            )

        if response.status_code == 200:
            img_url = response.json()["data"]["url"]
            print(f"Uploaded: {img_url}")
            results.append({"URL": url, "Screenshot URL": img_url})
        else:
            print(f"Upload failed for {url}")
    except Exception as e:
        print(f"Error processing {url}: {e}")

driver.quit()

# Save results to CSV
output_file = "screenshots_urls.csv"
pd.DataFrame(results).to_csv(output_file, index=False)
print(f"Results saved to {output_file}")
# Out:
# Screenshot saved: screenshot_0.png
# Uploaded: https://i.ibb.co/CpdD48ss/screenshot-0.png
# Screenshot saved: screenshot_1.png
# Uploaded: https://i.ibb.co/VpNCZ567/screenshot-1.png
# Screenshot saved: screenshot_2.png
# Uploaded: https://i.ibb.co/dJ7XgPn6/screenshot-2.png
# Screenshot saved: screenshot_3.png
# Uploaded: https://i.ibb.co/rK6hdz7x/screenshot-3.png
# Screenshot saved: screenshot_4.png
# Uploaded: https://i.ibb.co/rGcnKHG7/screenshot-4.png
# Screenshot saved: screenshot_5.png
# Uploaded: https://i.ibb.co/nqJyxGvb/screenshot-5.png
# Screenshot saved: screenshot_6.png
# Uploaded: https://i.ibb.co/zDHv0fm/screenshot-6.png
# Screenshot saved: screenshot_7.png
# Uploaded: https://i.ibb.co/WWJ7vcMm/screenshot-7.png
# Screenshot saved: screenshot_8.png
# Uploaded: https://i.ibb.co/mCbqSvtB/screenshot-8.png
# Screenshot saved: screenshot_9.png
# Uploaded: https://i.ibb.co/gbf4xw4S/screenshot-9.png
# Screenshot saved: screenshot_10.png
# ...

# %% [markdown]
# # New Section

# %%
import csv
import os
import json
import urllib.request
import urllib.error
import concurrent.futures

# File paths
input_file_path = os.path.expanduser("/content/web1_url - Sheet1.csv")
out_file_path = input_file_path.replace(".csv", "_results.csv")

# API configuration
BASE_URL = "https://api.pagepixels.com/snap"
ACCESS_TOKEN = "satyrkjDNv2C6HABRsQtyoY6ojChKL1_6l8cUXw3NLQ"

# Concurrency settings
MAX_CONCURRENT_REQUESTS = 10
test_count = 1  # Limit the number of rows processed during testing. 0 processes all rows.
start_after_url = ""  # Skip rows before this URL

def get_request_url(url):
    params = {
        "ttl": 1500,
        "url": url,
        "access_token": ACCESS_TOKEN,
        "json": "true",
        "no_cookie_banners": "true",
        "no_ads": "true",
        "time_zone": "US/Eastern",
    }
    return f"{BASE_URL}?{'&'.join(f'{k}={v}' for k, v in params.items())}"

def fetch_snapshot(url):
    """Fetch snapshot for a given URL and return the result."""
    request_url = get_request_url(url)
    try:
        with urllib.request.urlopen(request_url) as response:
            if response.status != 200:
                print(f"Error for {url}: HTTP {response.status}")
                return url, None

            response_data = response.read().decode('utf-8')
            json_response = json.loads(response_data)
            direct_link = json_response.get('direct_link')

            if not direct_link:
                print(f"Unexpected response for {url}: {json_response}")
                return url, None

            print(f"Snapshot for {url} succeeded: {direct_link}")
            return url, direct_link
    except urllib.error.HTTPError as e:
        print(f"HTTP error for {url}: {e.code} {e.reason}")
    except urllib.error.URLError as e:
        print(f"URL error for {url}: {e.reason}")
    except json.JSONDecodeError:
        print(f"Invalid JSON response for {url}")

    return url, None

def save_result(output_file_path, url, direct_link, is_new_file):
    """Appends a single result to the CSV file after each API call."""
    try:
        with open(output_file_path, 'a', newline='') as output_csv:
            fieldnames = ['url', 'direct_link']
            writer = csv.DictWriter(output_csv, fieldnames=fieldnames)

            if is_new_file:
                writer.writeheader()

            writer.writerow({'url': url, 'direct_link': direct_link})
    except Exception as e:
        print(f"Error writing result for {url}: {e}")

def process_csv(input_file_path, output_file_path, start_after_url, test_count):
    """Processes the input CSV with concurrent requests and saves results after each call."""
    is_new_file = not os.path.exists(output_file_path)
    urls_to_process = []

    try:
        with open(input_file_path, 'r') as csv_file:
            reader = csv.DictReader(csv_file)
            row_count = 0
            start_processing = start_after_url == ""

            for row in reader:
                url = row.get('url')
                print(row)
                if not url:
                    continue

                if not start_processing:
                    if url == start_after_url:
                        start_processing = True
                    continue

                urls_to_process.append(url)
                row_count += 1

                if test_count and row_count >= test_count:
                    break
    except FileNotFoundError:
        print(f"File not found: {input_file_path}")
        return
    except Exception as e:
        print(f"An error occurred: {e}")
        return

    with concurrent.futures.ThreadPoolExecutor(max_workers=MAX_CONCURRENT_REQUESTS) as executor:
        future_to_url = {executor.submit(fetch_snapshot, url): url for url in urls_to_process}
        for future in concurrent.futures.as_completed(future_to_url):
            url, direct_link = future.result()
            if direct_link:
                save_result(output_file_path, url, direct_link, is_new_file)
                is_new_file = False  # Ensure headers are written only once

    print(f"Processing complete. Results saved to {output_file_path}")

# Run the process
process_csv(input_file_path, out_file_path, start_after_url, test_count)
# Out:
# File not found: /content/web1_url - Sheet1.csv

# %%
# !pip install webdriver-manager
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import time
import requests
import pandas as pd
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager

# Set your ImgBB API key
IMGBB_API_KEY = "6d03c13353771a4dc84e84df64602b19"

# Setup Selenium WebDriver
chrome_options = Options()
chrome_options.add_argument("--headless")  # Run in headless mode
chrome_options.add_argument("--no-sandbox")
chrome_options.add_argument("--disable-dev-shm-usage")
service = Service(ChromeDriverManager().install())

# Store results
results = []

for url in urls:
    try:
        driver.get(url)
        time.sleep(2)  # Allow time for the page to load

        # Take a screenshot
        screenshot_path = f"screenshot_{urls.index(url)}.png"
        driver.save_screenshot(screenshot_path)
        print(f"Screenshot saved: {screenshot_path}")

        # Upload to ImgBB
        with open(screenshot_path, "rb") as file:
            response = requests.post(
                "https://api.imgbb.com/1/upload",
                params={"key": IMGBB_API_KEY},
                files={"image": file}
            )

        if response.status_code == 200:
            img_url = response.json()["data"]["url"]
            print(f"Uploaded: {img_url}")
            results.append({"URL": url, "Screenshot URL": img_url})
        else:
            print(f"Upload failed for {url}")
    except Exception as e:
        print(f"Error processing {url}: {e}")

driver.quit()

# Save results to CSV
output_file = "screenshots_urls.csv"
pd.DataFrame(results).to_csv(output_file, index=False)
print(f"Results saved to {output_file}")
# Out:
# Screenshot saved: screenshot_0.png
# Uploaded: https://i.ibb.co/bjyrQsZm/yogapodcollegestation-com.png
# Screenshot saved: screenshot_1.png
# Uploaded: https://i.ibb.co/r2jmpq8J/screenshot-1.png
# Screenshot saved: screenshot_2.png
# Uploaded: https://i.ibb.co/yBbNQkLg/www-lemkesfitnessandtraining-com.png
# Screenshot saved: screenshot_3.png
# Uploaded: https://i.ibb.co/V7m3VHN/santoshastudios-com.png
# Screenshot saved: screenshot_4.png
# Uploaded: https://i.ibb.co/xSXmffQT/screenshot-4.png
# Screenshot saved: screenshot_5.png
# Uploaded: https://i.ibb.co/rnm2JFy/joycollectiveyoga-com.png
# Screenshot saved: screenshot_6.png
# Uploaded: https://i.ibb.co/35KtbRQz/www-vitaltreeco-com.png
# Screenshot saved: screenshot_7.png
# Uploaded: https://i.ibb.co/d0qsmJHJ/www-bumblingcircusworkshop-com.png
# Screenshot saved: screenshot_8.png
# Uploaded: https://i.ibb.co/gFSHh1d4/screenshot-8.png
# Screenshot saved: screenshot_9.png
# Uploaded: https://i.ibb.co/jkQ9dqKR/screenshot-9.png
# ...

# %%
# !chrome://settings/help
# Out:
# /bin/bash: line 1: chrome://settings/help: No such file or directory

# %%
# !pip install --upgrade webdriver-manager

# %%
driver = webdriver.Chrome(service=service)
service = Service("chromedriver")

# %%
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.service import Service
from selenium import webdriver

service = Service(ChromeDriverManager().install())
driver = webdriver.Chrome(service=service)

# %%
import time
import requests
import pandas as pd
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager

# Set your ImgBB API key
IMGBB_API_KEY = "6d03c13353771a4dc84e84df64602b19"

# Setup Selenium WebDriver
chrome_options = Options()
chrome_options.add_argument("--headless")  # Run in headless mode
chrome_options.add_argument("--no-sandbox")
chrome_options.add_argument("--disable-dev-shm-usage")
chrome_options.add_argument("--start-maximized")  # Ensure full-screen mode
service = Service(ChromeDriverManager().install())
driver = webdriver.Chrome(service=service, options=chrome_options)

driver.set_window_size(1920, 1080)  # Set the window size explicitly

# Store results
results = []

for url in urls:
    try:
        driver.get(url)
        time.sleep(3)  # Allow time for the page to load

        # Ensure full-page screenshot
        total_height = driver.execute_script("return document.body.scrollHeight")
        driver.set_window_size(1920, total_height)

        # Take a screenshot
        screenshot_path = f"screenshot_{urls.index(url)}.png"
        driver.save_screenshot(screenshot_path)
        print(f"Screenshot saved: {screenshot_path}")

        # Upload to ImgBB
        with open(screenshot_path, "rb") as file:
            response = requests.post(
                "https://api.imgbb.com/1/upload",
                params={"key": IMGBB_API_KEY},
                files={"image": file}
            )

        if response.status_code == 200:
            img_url = response.json()["data"]["url"]
            print(f"Uploaded: {img_url}")
            results.append({"URL": url, "Screenshot URL": img_url})
        else:
            print(f"Upload failed for {url}")
    except Exception as e:
        print(f"Error processing {url}: {e}")

driver.quit()

# Save results to CSV
output_file = "screenshots_urls.csv"
pd.DataFrame(results).to_csv(output_file, index=False)
print(f"Results saved to {output_file}")
# Out:
# Screenshot saved: screenshot_0.png
# Uploaded: https://i.ibb.co/ZRkKtrR2/screenshot-0.png
# Screenshot saved: screenshot_1.png
# Uploaded: https://i.ibb.co/dzfdnm5/screenshot-1.png
# Screenshot saved: screenshot_2.png
# Uploaded: https://i.ibb.co/KjDDHSKv/screenshot-2.png
# Screenshot saved: screenshot_3.png
# Uploaded: https://i.ibb.co/vvh6mxRY/screenshot-3.png
# Screenshot saved: screenshot_4.png
# Uploaded: https://i.ibb.co/4wHXNCWh/screenshot-4.png
# Screenshot saved: screenshot_5.png
# Uploaded: https://i.ibb.co/Mxd756b1/screenshot-5.png
# Screenshot saved: screenshot_6.png

# %%
import time
import requests
import pandas as pd
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager

# Set your ImgBB API key
IMGBB_API_KEY = "6d03c13353771a4dc84e84df64602b19"

# Setup Selenium WebDriver
chrome_options = Options()
chrome_options.add_argument("--headless")  # Run in headless mode
chrome_options.add_argument("--no-sandbox")
chrome_options.add_argument("--disable-dev-shm-usage")
chrome_options.add_argument("--start-maximized")  # Start maximized
service = Service(ChromeDriverManager().install())

# Store results
results = []

for url in urls:
    try:
        driver.get(url)
        time.sleep(2)  # Allow time for the page to load

        # Set window size to full screen
        driver.set_window_size(1920, 1080)

        # Take a screenshot
        screenshot_path = f"screenshot_{urls.index(url)}.png"
        driver.save_screenshot(screenshot_path)
        print(f"Screenshot saved: {screenshot_path}")

        # Upload to ImgBB
        with open(screenshot_path, "rb") as file:
            response = requests.post(
                "https://api.imgbb.com/1/upload",
                params={"key": IMGBB_API_KEY},
                files={"image": file}
            )

        if response.status_code == 200:
            img_url = response.json()["data"]["url"]
            print(f"Uploaded: {img_url}")
            results.append({"URL": url, "Screenshot URL": img_url})
        else:
            print(f"Upload failed for {url}")
    except Exception as e:
        print(f"Error processing {url}: {e}")

driver.quit()

# Save results to CSV
output_file = "screenshots_urls.csv"
pd.DataFrame(results).to_csv(output_file, index=False)
print(f"Results saved to {output_file}")
# Out:
# WARNING:urllib3.connectionpool:Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7db671441510>: Failed to establish a new connection: [Errno 111] Connection refused')': /session/b51d9b93bc6b47f47620ab1bf6a3b2da/url
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7db671174310>: Failed to establish a new connection: [Errno 111] Connection refused')': /session/b51d9b93bc6b47f47620ab1bf6a3b2da/url
# ...
